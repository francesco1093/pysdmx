# %%
import os
os.chdir('..')

# %%
from pysdmx import get_codes, get_dimensions, get_dsd_identifier, get_flows, get_providers, get_timeseries, get_timeseries_table
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get timeseries as list

# %% [markdown]
# ### Timeseries data

# %%
ts = get_timeseries('ECB', id='EXR.A.USD.EUR.SP00.A')
print(ts)
# Out:
# [1999    1.065776
# 2000    0.923613
# 2001    0.895630
# 2002    0.945574
# 2003    1.131160
# 2004    1.243902
# 2005    1.244090
# 2006    1.255599
# 2007    1.370478
# 2008    1.470755
# 2009    1.394782
# 2010    1.325717
# 2011    1.391955
# 2012    1.284789
# 2013    1.328118
# 2014    1.328501
# 2015    1.109513
# 2016    1.106903
# 2017    1.129681
# 2018    1.180955
# 2019    1.119475
# 2020    1.142196
# 2021    1.182740
# 2022    1.053049
# Name: EXR.A.USD.EUR.SP00.A, dtype: float64]

# %% [markdown]
# ### Timeseries attributes

# %%
for k, v in ts[0].attrs.items():
    print(f"{k}: {v}")
    print()
# Out:
# OBS_STATUS: ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A']
#
# OBS_CONF: ['F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F']
#
# action: ['Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace', 'Replace']
#
# ...

# %% [markdown]
# ## Timeseries as Pandas DataFrame

# %%
get_timeseries_table('ECB', id='EXR.A.USD.EUR.SP00.A')
# Out:
#     OBS_VALUE TIME_PERIOD                    ID OBS_STATUS OBS_CONF   action  \
# 0    1.065776        1999  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 1    0.923613        2000  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 2    0.895630        2001  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 3    0.945574        2002  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 4    1.131160        2003  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 5    1.243902        2004  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 6    1.244090        2005  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 7    1.255599        2006  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 8    1.370478        2007  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 9    1.470755        2008  EXR.A.USD.EUR.SP00.A          A        F  Replace
# 10   1.394782        2009  EXR.A.USD.EUR.SP00.A          A        F  Replace
# ...

# %% [markdown]
# ## Plot timeseries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ts = get_timeseries('ECB', id='EXR.A.USD.EUR.SP00.A')
ts[0].plot()
# Out:
# <AxesSubplot: >
